# %%
#| default_exp local_laziness

# %%
# from nbdev.showdoc import *
import numpy as np
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # 02b Region Limited Laziness
#
# The standard diffusion curvature method can estimate the laziness well, but it often takes a large number of diffusions to estimate this laziness and escape the effects of local density fluctuations.
#
# This motivates an experiment: what if we *prevented* the diffusions from leaving the local area of interest? Then, perhaps, they wouldn't grow diffuse so easily, allowing curvature computation with fewer powers of diffusion.

# %%
import numpy as np
from diffusion_curvature.datasets import torus
from diffusion_curvature.core import DiffusionMatrix
from diffusion_curvature.core import plot_3d

# %%
#| export
from tqdm.notebook import trange
import numpy as np
def local_laziness(A, diffusion_powers = 8, aperture = 80, neighborhood = 1, dynamically_adjusting_neighborhood = False, smoothing=1, verbose=False):
    """Take a localized measure of diffusion laziness, with diffusion restricted to with the given aperture. Estimates curvature.

    Parameters
    ----------
    A : ndarray
        Affinity matrix of data (non-row normalized)
    diffusion_powers : int, optional
        The number of matrix powers to raise the diffusion operature, by default 8
    aperture : int, optional
        The number of nearest neighbors to which to limit the diffusion operator, by default 80
    neighborhood : int, optional
        The number of nearest neighbors of a point to use calculating laziness, by default 1
    dynamically_adjusting_neighborhood : bool, optional
        Whether the aperture and neighborhood should be based on thresholds derived over the dataset (False) or should expand to create the designated number of neighbors everywhere in the dataset (if True), by default False
    smoothing : int, optional
        Number of iterations of diffusion averaging to apply to the laziness values before returning, by default 1
    verbose : bool, optional
        Whether to print debugging statements and return extra debugging information, by default True

    Returns
    -------
    list
        Laziness value at each point
    """
    # First, a proof of concept: iterate through every point,
    # Make a sub-diffusion matrix for that point, consisting only of the nearest neighbors, 
    # And calculate the laziness for each value
    laziness_values = []
    # debugging
    list_of_apertures = []
    list_of_Ps = []
    list_of_Wsubs = []
    for i in trange(A.shape[0]):
        # Get the indices of the "aperture" closest points, as measured by the diffusion probabilities
        idxs = np.argsort(A[i])[-aperture:][::-1]
        # TODO Should these be sorted? Does it matter?
        # Create a sub-diffusion matrix. The pt i should be first.
        W_sub = A[idxs][:,idxs]
        degrees = np.diag(1/np.sum(W_sub,axis=1))
        P = degrees @ W_sub
        # Derive thresholds for the neighborhood partition
        # TODO Could reuse above idxs for greater efficiency
        thresholds = np.partition(P,-neighborhood)[:,-neighborhood]
        P_threshold = np.mean(thresholds) # TODO could also use min
        P_thresholded = (P >= P_threshold).astype(int)
        # Power the matrix
        P_powered = np.linalg.matrix_power(P,diffusion_powers)
        # take the diffusion probs of the neighborhood
        near_neighbors_only = P_powered * P_thresholded
        laziness_aggregate = np.sum(near_neighbors_only,axis=1)
        laziness_of_point = laziness_aggregate[0] 
        laziness_values.append(laziness_of_point)
        list_of_apertures.append(idxs)
        list_of_Ps.append(P_powered)
        list_of_Wsubs.append(W_sub)
    # Smoothing
    if smoothing is not None:  
        D = np.diag(1/np.sum(A,axis=1))
        P = D @ A 
        P_t = np.linalg.matrix_power(P,smoothing)
        ks_smoothed = P_t @ laziness_values
        laziness_values = ks_smoothed.squeeze()
    if verbose:
        return laziness_values, list_of_apertures, list_of_Ps, list_of_Wsubs
    return laziness_values

# %% [markdown]
# With the code written, let's test it on our old friend, the torus

# %%
X, ks = torus(n=5000)
A = DiffusionMatrix(X,kernel_type="adaptive anisotropic",k=20,affinity_matrix_only=True)
P = DiffusionMatrix(X,kernel_type="adaptive anisotropic",k=20,affinity_matrix_only=False)

# %%
A
# Out:
# array([[1.02905510e-04, 9.59025050e-09, 1.11411829e-05, ...,
#         9.60411836e-29, 1.51498661e-08, 5.84429425e-37],
#        [9.59025050e-09, 8.92910800e-05, 4.36453173e-07, ...,
#         1.37293943e-29, 1.27608437e-09, 3.78254688e-34],
#        [1.11411829e-05, 4.36453173e-07, 9.52505739e-05, ...,
#         3.92482681e-25, 7.00693037e-09, 2.63894273e-34],
#        ...,
#        [9.60411836e-29, 1.37293943e-29, 3.92482681e-25, ...,
#         1.01443258e-04, 6.94848776e-19, 5.67994428e-12],
#        [1.51498661e-08, 1.27608437e-09, 7.00693037e-09, ...,
#         6.94848776e-19, 1.17267004e-04, 5.00075287e-20],
#        [5.84429425e-37, 3.78254688e-34, 2.63894273e-34, ...,
#         5.67994428e-12, 5.00075287e-20, 1.15277718e-04]])

# %%
plot_3d(X,A[0])

# %% [markdown]
# ## Testing the method

# %%
aperture = 100
diffusion_powers = 16
neighborhood=20
smoothed = 2
ks, apertures, Ps, Ws = local_laziness(A, diffusion_powers=diffusion_powers, aperture=aperture, neighborhood=neighborhood,smoothing=smoothed, verbose=True)
# Out:
#   0%|          | 0/2461 [00:00<?, ?it/s]

# %% [markdown]
# Let's see what the aperture looked like

# %%
dist = np.zeros(len(X))
dist[apertures[0]] = 2
dist[0] = 1
plot_3d(X,distribution=dist,title="Aperture Size")

# %%
p = 0
diff_vals = Ps[p][0]
dist = np.zeros(len(X))
for i in range(len(apertures[p])):
    dist[apertures[p][i]] = diff_vals[i]
plot_3d(X,distribution=dist,title="Sub-diffusion matrix")

# %%
plot_3d(X,ks,title = f"Localized Laziness with ap={aperture}, t={diffusion_powers}, and nbhd={neighborhood}. Smoothing is {smoothed}.")

# %% [markdown]
# # Validation with Distribution Plots

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# What are the distributions of laziness values in three parts of the torus?

# %% [markdown]
# For a positively curved region, we expect the mass to remain clumped in the middle, hence there should be a smaller number of larger points.

# %%
p = 0
dist = Ps[p][0]
plt.hist(dist)
plt.title("+ Curvature")
# Out:
# Text(0.5, 1.0, '+ Curvature')

# %% [markdown]
# For a region of little curvature, we expect a more even spread.

# %%
p = 1
dist = Ps[p][0]
plt.hist(dist)
plt.title("0 Curvature")
# Out:
# Text(0.5, 1.0, '0 Curvature')

# %% [markdown]
# For a region of negative curvature, we expect the mass to be pushed to the sides, creating a greater number of not-quite-as-large points.

# %%
p = 2
dist = Ps[p][0]
plt.hist(dist)
plt.title("- Curvature")
# Out:
# Text(0.5, 1.0, '- Curvature')

# %% [markdown]
# # Validation with Laziness Decay Graphs

# %%
from diffusion_curvature.laziness_decay import laziness_decay

# %%
# This currently takes unreasonably long to run.
# decaying_lazy = laziness_decay(A, max_steps=40,aperture=100,adaptive_neighborhood=False,use_local_laziness=True, neighborhood=10)
# Out:
#   0%|          | 0/40 [00:00<?, ?it/s]
#   0%|          | 0/2461 [00:00<?, ?it/s]
#   0%|          | 0/2461 [00:00<?, ?it/s]
#   0%|          | 0/2461 [00:00<?, ?it/s]
#   0%|          | 0/2461 [00:00<?, ?it/s]
#   0%|          | 0/2461 [00:00<?, ?it/s]
#   0%|          | 0/2461 [00:00<?, ?it/s]
#   0%|          | 0/2461 [00:00<?, ?it/s]
#   0%|          | 0/2461 [00:00<?, ?it/s]
#   0%|          | 0/2461 [00:00<?, ?it/s]
#   0%|          | 0/2461 [00:00<?, ?it/s]
#   0%|          | 0/2461 [00:00<?, ?it/s]
#   0%|          | 0/2461 [00:00<?, ?it/s]
#   0%|          | 0/2461 [00:00<?, ?it/s]
#   0%|          | 0/2461 [00:00<?, ?it/s]
#   0%|          | 0/2461 [00:00<?, ?it/s]
#   0%|          | 0/2461 [00:00<?, ?it/s]
#   0%|          | 0/2461 [00:00<?, ?it/s]
#   0%|          | 0/2461 [00:00<?, ?it/s]
#   0%|          | 0/2461 [00:00<?, ?it/s]
#   0%|          | 0/2461 [00:00<?, ?it/s]
#   0%|          | 0/2461 [00:00<?, ?it/s]
#   0%|          | 0/2461 [00:00<?, ?it/s]
#   0%|          | 0/2461 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [62], line 1
# ----> 1 decaying_lazy = laziness_decay(A, max_steps=40,aperture=100,adaptive_neighborhood=False,use_local_laziness=True, neighborhood=10)
#
# File ~/Projects/diffusion_curvature/diffusion_curvature/laziness_decay.py:45, in laziness_decay(A, max_steps, aperture, neighborhood, smoothing, adaptive_neighborhood, non_lazy_diffusion, use_local_laziness)
#      43 for t in trange(1,max_steps+1):
#      44     if use_local_laziness:
# ---> 45         laziness = local_laziness(A,diffusion_powers = t,aperture=aperture,neighborhood=neighborhood,smoothing=1)
#      46     else:
#      47         P_t = P_t @ P
#
# File ~/Projects/diffusion_curvature/diffusion_curvature/local_laziness.py:56, in local_laziness(A, diffusion_powers, aperture, neighborhood, dynamically_adjusting_neighborhood, smoothing, verbose)
#      54 P_thresholded = (P >= P_threshold).astype(int)
#      55 # Power the matrix
# ---> 56 P_powered = np.linalg.matrix_power(P,diffusion_powers)
#      57 # take the diffusion probs of the neighborhood
#      58 near_neighbors_only = P_powered * P_thresholded
#
# File <__array_function__ internals>:180, in matrix_power(*args, **kwargs)
#
# File ~/miniforge3/envs/diffusion_curvature/lib/python3.10/site-packages/numpy/linalg/linalg.py:668, in matrix_power(a, n)
#     666 z = result = None
#     667 while n > 0:
# --> 668     z = a if z is None else fmatmul(z, z)
#     669     n, bit = divmod(n, 2)
#     670     if bit:
#
# KeyboardInterrupt:

# %%
# dist = np.zeros(len(X))
# dist[0] = 1
# dist[1] = 1
# dist[2] = 1
# plot_3d(X,dist,cmap="cool")

# %%
# fig, ax = plt.subplots(1,figsize=(10,10))
# ax.plot(decaying_lazy[0],color='green',label='Positive')
# ax.plot(decaying_lazy[2],color='blue',label='Zero')
# ax.plot(decaying_lazy[1],color='red',label='Negative')
# ax.legend()
# ax.set_xlabel("Diffusion Time Steps")
# ax.set_ylabel("Laziness")
# Out:
# Text(0, 0.5, 'Laziness')

# %% [markdown]
# Beautiful! The region-limited laziness value differentiates between negative, positive, and low positive curvature regions after only five iterations of diffusion, after which it stabilizes very quickly.
# Compare this to the laziness decay graphs of the traditional laziness measurement, which take upwards of 60 diffusion powers to differentiate the regions.

# %% [markdown]
# But note: even on the very first diffusion iteration, the negative and positive regions have been distinguished. Hence, this effect may be due to the same neighborhood-size interference we noted earlier.
